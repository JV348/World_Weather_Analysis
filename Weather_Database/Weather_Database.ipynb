# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6a81fe40de07c2859c65905509f3e6db

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Retrieve data 
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 791

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Use enumerate() to reference the index and the city in the list 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Handle API Request Errors with try-except Blocks; testing code 
    # Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_describe = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | erice
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | bosaso
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | tarko-sale
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | kharp
# Processing Record 17 of Set 1 | sur
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | casa nova
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | sinnamary
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | sao jose da coroa grande
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | kutum
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | brae
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | arcachon
# Processing Record 36 of Set 1 | hovd
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | mpanda
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | mlada vozice
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | kalmunai
# Processing Record 44 of Set 1 | livny
# Processing Record 45 of Set 1 | marquette
# Processing Record 46 of Set 1 | vila velha
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | teguise
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | yendi
# Processing Record 5 of Set 2 | hamilton
# Processing Record 6 of Set 2 | salihli
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | cayenne
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 2 | chara
# Processing Record 16 of Set 2 | wilmslow
# Processing Record 17 of Set 2 | berlevag
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | ewa beach
# Processing Record 21 of Set 2 | tillabery
# City not found. Skipping...
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | adrar
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | winchester
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | dezful
# Processing Record 28 of Set 2 | tuatapere
# Processing Record 29 of Set 2 | bayonet point
# Processing Record 30 of Set 2 | bukama
# Processing Record 31 of Set 2 | zheleznodorozhnyy
# Processing Record 32 of Set 2 | piacabucu
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | damnoen saduak
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | umm kaddadah
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | westerland
# Processing Record 39 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 2 | castlemaine
# Processing Record 41 of Set 2 | maceio
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | la ronge
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | goundam
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | saint-joseph
# Processing Record 49 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 2 | vostok
# Processing Record 1 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | general pico
# Processing Record 4 of Set 3 | bayir
# Processing Record 5 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | mastic beach
# Processing Record 8 of Set 3 | darhan
# Processing Record 9 of Set 3 | redlands
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | ahar
# Processing Record 12 of Set 3 | siderno
# Processing Record 13 of Set 3 | broken hill
# Processing Record 14 of Set 3 | montefiascone
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | vega de alatorre
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | sioux lookout
# Processing Record 21 of Set 3 | camana
# Processing Record 22 of Set 3 | plettenberg bay
# Processing Record 23 of Set 3 | mataura
# Processing Record 24 of Set 3 | dire
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | thunder bay
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | kudahuvadhoo
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | awbari
# Processing Record 32 of Set 3 | sao joao da barra
# Processing Record 33 of Set 3 | macamic
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | novikovo
# Processing Record 36 of Set 3 | ndioum
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | kolokani
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | clarksburg
# Processing Record 42 of Set 3 | kandrian
# Processing Record 43 of Set 3 | charters towers
# Processing Record 44 of Set 3 | maseru
# Processing Record 45 of Set 3 | hami
# Processing Record 46 of Set 3 | rabat
# Processing Record 47 of Set 3 | aranda de duero
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | neiafu
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | marawi
# Processing Record 2 of Set 4 | santa maria del oro
# Processing Record 3 of Set 4 | yining
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | znamensk
# Processing Record 6 of Set 4 | astoria
# Processing Record 7 of Set 4 | yumen
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | xiamen
# Processing Record 10 of Set 4 | novyy urengoy
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | imeni poliny osipenko
# Processing Record 14 of Set 4 | lensk
# Processing Record 15 of Set 4 | angoche
# Processing Record 16 of Set 4 | bac lieu
# Processing Record 17 of Set 4 | nuuk
# Processing Record 18 of Set 4 | hastings
# Processing Record 19 of Set 4 | vodnyy
# Processing Record 20 of Set 4 | kulhudhuffushi
# Processing Record 21 of Set 4 | great falls
# Processing Record 22 of Set 4 | smithers
# Processing Record 23 of Set 4 | westport
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | lahij
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | sergeyevka
# Processing Record 28 of Set 4 | meulaboh
# Processing Record 29 of Set 4 | ashland
# Processing Record 30 of Set 4 | vredendal
# Processing Record 31 of Set 4 | englewood
# Processing Record 32 of Set 4 | kargasok
# Processing Record 33 of Set 4 | sheltozero
# Processing Record 34 of Set 4 | puerto escondido
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | sasovo
# Processing Record 37 of Set 4 | aketi
# Processing Record 38 of Set 4 | la rioja
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | konstantinovskoye
# Processing Record 41 of Set 4 | midleton
# Processing Record 42 of Set 4 | soyo
# Processing Record 43 of Set 4 | saurimo
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | dehloran
# Processing Record 46 of Set 4 | muzhi
# Processing Record 47 of Set 4 | dali
# Processing Record 48 of Set 4 | havre-saint-pierre
# Processing Record 49 of Set 4 | bryan
# Processing Record 50 of Set 4 | monte patria
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | de aar
# Processing Record 3 of Set 5 | thinadhoo
# Processing Record 4 of Set 5 | nome
# Processing Record 5 of Set 5 | havelock
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | touros
# Processing Record 8 of Set 5 | uruzgan
# Processing Record 9 of Set 5 | esmeralda
# Processing Record 10 of Set 5 | moerai
# Processing Record 11 of Set 5 | phonhong
# Processing Record 12 of Set 5 | new norfolk
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | peniche
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | dikson
# Processing Record 17 of Set 5 | belmonte
# Processing Record 18 of Set 5 | nizwa
# Processing Record 19 of Set 5 | shenzhen
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | lachi
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | longyearbyen
# Processing Record 24 of Set 5 | terenos
# Processing Record 25 of Set 5 | port-gentil
# Processing Record 26 of Set 5 | amahai
# Processing Record 27 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 5 | pevek
# Processing Record 29 of Set 5 | paramonga
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | poum
# Processing Record 33 of Set 5 | cherskiy
# Processing Record 34 of Set 5 | lypnyazhka
# Processing Record 35 of Set 5 | batesville
# Processing Record 36 of Set 5 | dasoguz
# Processing Record 37 of Set 5 | sanandaj
# Processing Record 38 of Set 5 | port pirie
# Processing Record 39 of Set 5 | alice springs
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | deputatskiy
# Processing Record 44 of Set 5 | san cristobal
# Processing Record 45 of Set 5 | neuquen
# Processing Record 46 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 5 | tocache
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | khasan
# Processing Record 1 of Set 6 | santana do matos
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 6 | srednekolymsk
# Processing Record 5 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 6 | beidao
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | korla
# Processing Record 9 of Set 6 | charyshskoye
# Processing Record 10 of Set 6 | sonkovo
# Processing Record 11 of Set 6 | provideniya
# Processing Record 12 of Set 6 | santa maria do para
# Processing Record 13 of Set 6 | lahat
# Processing Record 14 of Set 6 | borujan
# City not found. Skipping...
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | balykshi
# Processing Record 17 of Set 6 | georgetown
# Processing Record 18 of Set 6 | ulaangom
# Processing Record 19 of Set 6 | lazaro cardenas
# Processing Record 20 of Set 6 | qaanaaq
# Processing Record 21 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | juneau
# Processing Record 24 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 6 | itarema
# Processing Record 26 of Set 6 | bambanglipuro
# Processing Record 27 of Set 6 | mapiripan
# Processing Record 28 of Set 6 | liverpool
# Processing Record 29 of Set 6 | biak
# Processing Record 30 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 6 | palauig
# Processing Record 32 of Set 6 | sisimiut
# Processing Record 33 of Set 6 | miyako
# Processing Record 34 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 6 | kontagora
# Processing Record 36 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 6 | tamandare
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | kargat
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | pengcheng
# Processing Record 42 of Set 6 | guilford
# Processing Record 43 of Set 6 | vanavara
# Processing Record 44 of Set 6 | terrace
# Processing Record 45 of Set 6 | pangnirtung
# Processing Record 46 of Set 6 | ciudad bolivar
# Processing Record 47 of Set 6 | shimoda
# Processing Record 48 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 49 of Set 6 | pingliang
# Processing Record 50 of Set 6 | pallasovka
# Processing Record 1 of Set 7 | balakhta
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | honiara
# Processing Record 4 of Set 7 | pisco
# Processing Record 5 of Set 7 | sitka
# Processing Record 6 of Set 7 | toora-khem
# Processing Record 7 of Set 7 | goderich
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | ridgecrest
# Processing Record 10 of Set 7 | coihaique
# Processing Record 11 of Set 7 | laguna
# Processing Record 12 of Set 7 | marsa matruh
# Processing Record 13 of Set 7 | sobolevo
# Processing Record 14 of Set 7 | perth
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | iqaluit
# Processing Record 17 of Set 7 | tomatlan
# Processing Record 18 of Set 7 | corinto
# Processing Record 19 of Set 7 | kibaya
# Processing Record 20 of Set 7 | chuy
# Processing Record 21 of Set 7 | ribas do rio pardo
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | sibolga
# Processing Record 24 of Set 7 | porto novo
# Processing Record 25 of Set 7 | makakilo city
# Processing Record 26 of Set 7 | haverfordwest
# Processing Record 27 of Set 7 | kampene
# Processing Record 28 of Set 7 | bemidji
# Processing Record 29 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | san ramon
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | bathsheba
# Processing Record 34 of Set 7 | inver grove heights
# Processing Record 35 of Set 7 | canas
# Processing Record 36 of Set 7 | avarua
# Processing Record 37 of Set 7 | guanica
# Processing Record 38 of Set 7 | hobyo
# Processing Record 39 of Set 7 | chagoda
# Processing Record 40 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 41 of Set 7 | puri
# Processing Record 42 of Set 7 | asau
# Processing Record 43 of Set 7 | cabo san lucas
# Processing Record 44 of Set 7 | tiksi
# Processing Record 45 of Set 7 | dedougou
# Processing Record 46 of Set 7 | laizhou
# Processing Record 47 of Set 7 | mehamn
# Processing Record 48 of Set 7 | moree
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | vangaindrano
# Processing Record 1 of Set 8 | bella union
# Processing Record 2 of Set 8 | jiuquan
# Processing Record 3 of Set 8 | mamlyutka
# Processing Record 4 of Set 8 | mul
# Processing Record 5 of Set 8 | roald
# Processing Record 6 of Set 8 | banyo
# Processing Record 7 of Set 8 | galle
# Processing Record 8 of Set 8 | roches noires
# City not found. Skipping...
# Processing Record 9 of Set 8 | richmond
# Processing Record 10 of Set 8 | rabo de peixe
# Processing Record 11 of Set 8 | sao miguel do araguaia
# Processing Record 12 of Set 8 | port lincoln
# Processing Record 13 of Set 8 | beringovskiy
# Processing Record 14 of Set 8 | kaeng khlo
# City not found. Skipping...
# Processing Record 15 of Set 8 | verkhnyaya sinyachikha
# Processing Record 16 of Set 8 | koslan
# Processing Record 17 of Set 8 | balurghat
# Processing Record 18 of Set 8 | ndjole
# Processing Record 19 of Set 8 | maarianhamina
# Processing Record 20 of Set 8 | wittmund
# Processing Record 21 of Set 8 | college
# Processing Record 22 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | agucadoura
# Processing Record 25 of Set 8 | mount isa
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | dwarka
# Processing Record 28 of Set 8 | hilo
# Processing Record 29 of Set 8 | sainte-anne-des-monts
# Processing Record 30 of Set 8 | chabahar
# Processing Record 31 of Set 8 | san andres
# Processing Record 32 of Set 8 | pacific grove
# Processing Record 33 of Set 8 | tabou
# Processing Record 34 of Set 8 | lipay
# Processing Record 35 of Set 8 | khao yoi
# Processing Record 36 of Set 8 | halifax
# Processing Record 37 of Set 8 | krasnoselkup
# Processing Record 38 of Set 8 | vanimo
# Processing Record 39 of Set 8 | abnub
# Processing Record 40 of Set 8 | sun valley
# Processing Record 41 of Set 8 | svetlogorsk
# Processing Record 42 of Set 8 | ciro marina
# Processing Record 43 of Set 8 | christchurch
# Processing Record 44 of Set 8 | te anau
# Processing Record 45 of Set 8 | folkestone
# Processing Record 46 of Set 8 | orange
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | hollins
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 1 of Set 9 | bandarbeyla
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | ust-kan
# Processing Record 4 of Set 9 | shizunai
# Processing Record 5 of Set 9 | tingi
# Processing Record 6 of Set 9 | salamanca
# Processing Record 7 of Set 9 | gilgit
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | placido de castro
# Processing Record 10 of Set 9 | lima
# Processing Record 11 of Set 9 | soto
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | nanchang
# Processing Record 14 of Set 9 | carballo
# Processing Record 15 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 16 of Set 9 | kirakira
# Processing Record 17 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 9 | muslyumovo
# Processing Record 19 of Set 9 | koumac
# Processing Record 20 of Set 9 | maraba
# Processing Record 21 of Set 9 | lerwick
# Processing Record 22 of Set 9 | motygino
# Processing Record 23 of Set 9 | fare
# Processing Record 24 of Set 9 | nemuro
# Processing Record 25 of Set 9 | pahrump
# Processing Record 26 of Set 9 | nizhniy ufaley
# Processing Record 27 of Set 9 | hailey
# Processing Record 28 of Set 9 | lagunas
# Processing Record 29 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 30 of Set 9 | miracema do tocantins
# Processing Record 31 of Set 9 | dubove
# Processing Record 32 of Set 9 | rach gia
# Processing Record 33 of Set 9 | asfi
# Processing Record 34 of Set 9 | payson
# Processing Record 35 of Set 9 | dingle
# Processing Record 36 of Set 9 | litayen
# City not found. Skipping...
# Processing Record 37 of Set 9 | yerbogachen
# Processing Record 38 of Set 9 | dosso
# Processing Record 39 of Set 9 | dashitou
# Processing Record 40 of Set 9 | shiraz
# Processing Record 41 of Set 9 | oranjemund
# Processing Record 42 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 9 | bairiki
# Processing Record 44 of Set 9 | gobabis
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | boa vista
# Processing Record 47 of Set 9 | stornoway
# Processing Record 48 of Set 9 | katsuura
# Processing Record 49 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | colares
# Processing Record 1 of Set 10 | bilma
# Processing Record 2 of Set 10 | gravdal
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | kovdor
# Processing Record 5 of Set 10 | kabo
# Processing Record 6 of Set 10 | pocone
# Processing Record 7 of Set 10 | watsa
# Processing Record 8 of Set 10 | terney
# Processing Record 9 of Set 10 | wilmington
# Processing Record 10 of Set 10 | villa bruzual
# Processing Record 11 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 10 | praia
# Processing Record 13 of Set 10 | durango
# Processing Record 14 of Set 10 | palafrugell
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | gucheng
# Processing Record 17 of Set 10 | ouesso
# Processing Record 18 of Set 10 | pietroasa
# Processing Record 19 of Set 10 | najran
# Processing Record 20 of Set 10 | severnyy
# Processing Record 21 of Set 10 | bulolo
# Processing Record 22 of Set 10 | palmerston
# Processing Record 23 of Set 10 | mount gambier
# Processing Record 24 of Set 10 | edd
# Processing Record 25 of Set 10 | luwingu
# Processing Record 26 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 10 | yar-sale
# Processing Record 28 of Set 10 | nagayo
# Processing Record 29 of Set 10 | loukhi
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | puksoozero
# Processing Record 32 of Set 10 | linden
# Processing Record 33 of Set 10 | bani walid
# Processing Record 34 of Set 10 | huilong
# Processing Record 35 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 10 | oppdal
# Processing Record 37 of Set 10 | srandakan
# Processing Record 38 of Set 10 | pemba
# Processing Record 39 of Set 10 | kamaishi
# Processing Record 40 of Set 10 | saint-jerome
# Processing Record 41 of Set 10 | rocha
# Processing Record 42 of Set 10 | severnoye
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | plock
# Processing Record 45 of Set 10 | okato
# Processing Record 46 of Set 10 | elliot lake
# Processing Record 47 of Set 10 | port hawkesbury
# Processing Record 48 of Set 10 | hasaki
# Processing Record 49 of Set 10 | tromso
# Processing Record 50 of Set 10 | kapiri mposhi
# Processing Record 1 of Set 11 | half moon bay
# Processing Record 2 of Set 11 | new plymouth
# Processing Record 3 of Set 11 | kamenka
# Processing Record 4 of Set 11 | betare oya
# Processing Record 5 of Set 11 | dhidhdhoo
# Processing Record 6 of Set 11 | klaksvik
# Processing Record 7 of Set 11 | isangel
# Processing Record 8 of Set 11 | hella
# Processing Record 9 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 11 | praia da vitoria
# Processing Record 11 of Set 11 | noumea
# Processing Record 12 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 11 | norman wells
# Processing Record 14 of Set 11 | tiznit
# Processing Record 15 of Set 11 | rincon
# Processing Record 16 of Set 11 | panyutyne
# Processing Record 17 of Set 11 | ede
# Processing Record 18 of Set 11 | gualeguay
# Processing Record 19 of Set 11 | chenzhou
# Processing Record 20 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 11 | aksarka
# Processing Record 22 of Set 11 | ossora
# Processing Record 23 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 24 of Set 11 | japura
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | qasigiannguit
# Processing Record 27 of Set 11 | imbituba
# Processing Record 28 of Set 11 | shorewood
# Processing Record 29 of Set 11 | beloha
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | juba
# Processing Record 32 of Set 11 | chokwe
# Processing Record 33 of Set 11 | emerald
# Processing Record 34 of Set 11 | itoman
# Processing Record 35 of Set 11 | bulgan
# Processing Record 36 of Set 11 | homer
# Processing Record 37 of Set 11 | abay
# Processing Record 38 of Set 11 | znamenskoye
# Processing Record 39 of Set 11 | muros
# Processing Record 40 of Set 11 | ulkan
# Processing Record 41 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 11 | rawson
# Processing Record 43 of Set 11 | candido mendes
# Processing Record 44 of Set 11 | yachimata
# Processing Record 45 of Set 11 | kristiinankaupunki
# Processing Record 46 of Set 11 | taburao
# City not found. Skipping...
# Processing Record 47 of Set 11 | mountain home
# Processing Record 48 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 11 | chapais
# Processing Record 50 of Set 11 | prince rupert
# Processing Record 1 of Set 12 | pingyin
# Processing Record 2 of Set 12 | anqing
# Processing Record 3 of Set 12 | sakakah
# Processing Record 4 of Set 12 | trincomalee
# Processing Record 5 of Set 12 | macau
# Processing Record 6 of Set 12 | tacna
# Processing Record 7 of Set 12 | lamu
# Processing Record 8 of Set 12 | elliot
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | karratha
# Processing Record 11 of Set 12 | waltershausen
# Processing Record 12 of Set 12 | kargil
# Processing Record 13 of Set 12 | iskateley
# Processing Record 14 of Set 12 | jacqueville
# Processing Record 15 of Set 12 | cimislia
# Processing Record 16 of Set 12 | hokitika
# Processing Record 17 of Set 12 | safaga
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | husavik
# Processing Record 20 of Set 12 | basco
# Processing Record 21 of Set 12 | flin flon
# Processing Record 22 of Set 12 | ginir
# Processing Record 23 of Set 12 | da nang
# Processing Record 24 of Set 12 | la cruz
# Processing Record 25 of Set 12 | carutapera
# Processing Record 26 of Set 12 | sao filipe
# Processing Record 27 of Set 12 | ulladulla
# Processing Record 28 of Set 12 | palmer
# Processing Record 29 of Set 12 | los llanos de aridane
# Processing Record 30 of Set 12 | aklavik
# Processing Record 31 of Set 12 | naron
# Processing Record 32 of Set 12 | hit
# Processing Record 33 of Set 12 | bushehr
# Processing Record 34 of Set 12 | guiglo
# Processing Record 35 of Set 12 | bajil
# Processing Record 36 of Set 12 | graham
# Processing Record 37 of Set 12 | benguela
# Processing Record 38 of Set 12 | visby
# Processing Record 39 of Set 12 | morehead
# Processing Record 40 of Set 12 | cockburn town
# Processing Record 41 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 12 | saint-louis
# Processing Record 43 of Set 12 | orlik
# Processing Record 44 of Set 12 | panjab
# Processing Record 45 of Set 12 | waddan
# Processing Record 46 of Set 12 | burns lake
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | sidvokodvo
# Processing Record 1 of Set 13 | coihueco
# Processing Record 2 of Set 13 | paita
# Processing Record 3 of Set 13 | kurilsk
# Processing Record 4 of Set 13 | camacha
# Processing Record 5 of Set 13 | yanam
# Processing Record 6 of Set 13 | bairnsdale
# Processing Record 7 of Set 13 | sicamous
# Processing Record 8 of Set 13 | dong xoai
# Processing Record 9 of Set 13 | burdur
# Processing Record 10 of Set 13 | izhma
# Processing Record 11 of Set 13 | taltal
# Processing Record 12 of Set 13 | melfi
# Processing Record 13 of Set 13 | mattru
# Processing Record 14 of Set 13 | riviere-au-renard
# Processing Record 15 of Set 13 | namibe
# Processing Record 16 of Set 13 | kiunga
# Processing Record 17 of Set 13 | saint-leu
# Processing Record 18 of Set 13 | praya
# Processing Record 19 of Set 13 | urusha
# Processing Record 20 of Set 13 | alta floresta
# Processing Record 21 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 13 | zilair
# Processing Record 23 of Set 13 | tessalit
# Processing Record 24 of Set 13 | alugan
# Processing Record 25 of Set 13 | porto san giorgio
# Processing Record 26 of Set 13 | kawalu
# Processing Record 27 of Set 13 | ushumun
# Processing Record 28 of Set 13 | ghanzi
# Processing Record 29 of Set 13 | san patricio
# Processing Record 30 of Set 13 | wattegama
# Processing Record 31 of Set 13 | raga
# Processing Record 32 of Set 13 | mogadishu
# Processing Record 33 of Set 13 | nenjiang
# Processing Record 34 of Set 13 | ko samui
# Processing Record 35 of Set 13 | bubaque
# Processing Record 36 of Set 13 | inhambane
# Processing Record 37 of Set 13 | stokmarknes
# Processing Record 38 of Set 13 | boulsa
# Processing Record 39 of Set 13 | yulara
# Processing Record 40 of Set 13 | high level
# Processing Record 41 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 42 of Set 13 | north branch
# Processing Record 43 of Set 13 | belyy yar
# Processing Record 44 of Set 13 | batemans bay
# Processing Record 45 of Set 13 | luanda
# Processing Record 46 of Set 13 | aripuana
# Processing Record 47 of Set 13 | shingu
# Processing Record 48 of Set 13 | luancheng
# Processing Record 49 of Set 13 | zelenoborsk
# Processing Record 50 of Set 13 | faya
# Processing Record 1 of Set 14 | akdagmadeni
# Processing Record 2 of Set 14 | gura humorului
# Processing Record 3 of Set 14 | angra
# City not found. Skipping...
# Processing Record 4 of Set 14 | muncar
# Processing Record 5 of Set 14 | ekhabi
# Processing Record 6 of Set 14 | kamogawa
# Processing Record 7 of Set 14 | lata
# Processing Record 8 of Set 14 | yellamanchili
# City not found. Skipping...
# Processing Record 9 of Set 14 | kindersley
# Processing Record 10 of Set 14 | anadyr
# Processing Record 11 of Set 14 | morondava
# Processing Record 12 of Set 14 | lublin
# Processing Record 13 of Set 14 | nanga eboko
# Processing Record 14 of Set 14 | qui nhon
# Processing Record 15 of Set 14 | north bend
# Processing Record 16 of Set 14 | marica
# Processing Record 17 of Set 14 | kashi
# Processing Record 18 of Set 14 | imamoglu
# Processing Record 19 of Set 14 | abu dhabi
# Processing Record 20 of Set 14 | northam
# Processing Record 21 of Set 14 | jieshi
# Processing Record 22 of Set 14 | venado
# Processing Record 23 of Set 14 | evensk
# Processing Record 24 of Set 14 | suba
# Processing Record 25 of Set 14 | vardo
# Processing Record 26 of Set 14 | patterson
# Processing Record 27 of Set 14 | lasa
# Processing Record 28 of Set 14 | abha
# Processing Record 29 of Set 14 | bowen
# Processing Record 30 of Set 14 | provost
# Processing Record 31 of Set 14 | rahatgarh
# Processing Record 32 of Set 14 | kloulklubed
# Processing Record 33 of Set 14 | cacu
# Processing Record 34 of Set 14 | usinsk
# Processing Record 35 of Set 14 | zhigansk
# Processing Record 36 of Set 14 | sechura
# Processing Record 37 of Set 14 | lakatoro
# Processing Record 38 of Set 14 | scottsbluff
# Processing Record 39 of Set 14 | sokoni
# Processing Record 40 of Set 14 | jijiga
# Processing Record 41 of Set 14 | champua
# Processing Record 42 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 14 | rexburg
# Processing Record 44 of Set 14 | sanger
# Processing Record 45 of Set 14 | qatana
# Processing Record 46 of Set 14 | vzmorye
# Processing Record 47 of Set 14 | payakumbuh
# Processing Record 48 of Set 14 | gurjaani
# Processing Record 49 of Set 14 | ostrovnoy
# Processing Record 50 of Set 14 | belaya gora
# Processing Record 1 of Set 15 | carmen
# Processing Record 2 of Set 15 | aksha
# Processing Record 3 of Set 15 | khandyga
# Processing Record 4 of Set 15 | hualmay
# Processing Record 5 of Set 15 | nordby
# Processing Record 6 of Set 15 | camopi
# Processing Record 7 of Set 15 | kavaratti
# Processing Record 8 of Set 15 | hay river
# Processing Record 9 of Set 15 | port keats
# Processing Record 10 of Set 15 | bay roberts
# Processing Record 11 of Set 15 | lashio
# Processing Record 12 of Set 15 | kadom
# Processing Record 13 of Set 15 | mitsamiouli
# Processing Record 14 of Set 15 | saint-pierre
# Processing Record 15 of Set 15 | lithakia
# Processing Record 16 of Set 15 | araouane
# Processing Record 17 of Set 15 | huarmey
# Processing Record 18 of Set 15 | kurumkan
# Processing Record 19 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 15 | merauke
# Processing Record 21 of Set 15 | moose factory
# Processing Record 22 of Set 15 | wajir
# Processing Record 23 of Set 15 | frontera
# Processing Record 24 of Set 15 | akyab
# Processing Record 25 of Set 15 | wahpeton
# Processing Record 26 of Set 15 | benton harbor
# Processing Record 27 of Set 15 | pasni
# Processing Record 28 of Set 15 | pangody
# Processing Record 29 of Set 15 | bambous virieux
# Processing Record 30 of Set 15 | buraydah
# Processing Record 31 of Set 15 | ryotsu
# Processing Record 32 of Set 15 | khorixas
# Processing Record 33 of Set 15 | nerchinskiy zavod
# Processing Record 34 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 35 of Set 15 | cowansville
# Processing Record 36 of Set 15 | charlottesville
# Processing Record 37 of Set 15 | masyaf
# Processing Record 38 of Set 15 | alwar tirunagari
# Processing Record 39 of Set 15 | soma
# Processing Record 40 of Set 15 | pangai
# Processing Record 41 of Set 15 | xunchang
# Processing Record 42 of Set 15 | simao
# Processing Record 43 of Set 15 | pucallpa
# Processing Record 44 of Set 15 | polyarnyy
# Processing Record 45 of Set 15 | axim
# Processing Record 46 of Set 15 | gold coast
# Processing Record 47 of Set 15 | shelburne
# Processing Record 48 of Set 15 | warrington
# Processing Record 49 of Set 15 | brigantine
# Processing Record 50 of Set 15 | ust-tsilma
# Processing Record 1 of Set 16 | mali
# Processing Record 2 of Set 16 | quatre cocos
# Processing Record 3 of Set 16 | luziania
# Processing Record 4 of Set 16 | abadiania
# Processing Record 5 of Set 16 | daryapur
# Processing Record 6 of Set 16 | batticaloa
# Processing Record 7 of Set 16 | ilhabela
# Processing Record 8 of Set 16 | pangoa
# Processing Record 9 of Set 16 | asino
# Processing Record 10 of Set 16 | semirom
# Processing Record 11 of Set 16 | grand gaube
# Processing Record 12 of Set 16 | emba
# Processing Record 13 of Set 16 | ngunguru
# Processing Record 14 of Set 16 | swan hill
# Processing Record 15 of Set 16 | san carlos de bariloche
# Processing Record 16 of Set 16 | loandjili
# Processing Record 17 of Set 16 | kusu
# Processing Record 18 of Set 16 | drumheller
# Processing Record 19 of Set 16 | snyder
# Processing Record 20 of Set 16 | teya
# Processing Record 21 of Set 16 | kaeo
# Processing Record 22 of Set 16 | ipixuna
# Processing Record 23 of Set 16 | paamiut
# Processing Record 24 of Set 16 | ketchikan
# Processing Record 25 of Set 16 | kalaleh
# Processing Record 26 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 16 | jumla
# Processing Record 28 of Set 16 | salinas
# Processing Record 29 of Set 16 | havoysund
# Processing Record 30 of Set 16 | athens
# Processing Record 31 of Set 16 | aktau
# Processing Record 32 of Set 16 | champerico
# Processing Record 33 of Set 16 | bhag
# Processing Record 34 of Set 16 | ust-nera
# Processing Record 35 of Set 16 | constitucion
# Processing Record 36 of Set 16 | moron
# Processing Record 37 of Set 16 | banfora
# Processing Record 38 of Set 16 | morgan city
# Processing Record 39 of Set 16 | robertsport
# Processing Record 40 of Set 16 | estevan
# Processing Record 41 of Set 16 | bonavista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
WeatherPy_Database = city_data_df[new_column_order]
WeatherPy_Database.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0  Severo-Kurilsk      RU  2022-01-31 06:34:53  50.6789  156.1250     27.82
# 1           Erice      IT  2022-01-31 06:34:53  38.0370   12.5865     48.67
# 2          Lompoc      US  2022-01-31 06:34:54  34.6391 -120.4579     55.13
# 3     Tuktoyaktuk      CA  2022-01-31 06:34:54  69.4541 -133.0374     -0.40
# 4          Bosaso      SO  2022-01-31 06:34:54  11.2842   49.1816     76.98
# 5       Upernavik      GL  2022-01-31 06:34:55  72.7868  -56.1549    -13.94
# 6         Salalah      OM  2022-01-31 06:34:55  17.0151   54.0924     75.29
# 7      Chokurdakh      RU  2022-01-31 06:34:56  70.6333  147.9167    -20.09
# 8    Punta Arenas      CL  2022-01-31 06:32:25 -53.1500  -70.9167     48.31
# 9      Tarko-Sale      RU  2022-01-31 06:34:56  64.9225   77.7850      6.33
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        77          80       13.76          light snow
# 1        82          75       16.11       broken clouds
# 2        88          69       13.00       broken clouds
# 3        78         100       23.02          light snow
# 4        78          20        5.75          few clouds
# 5        89         100        6.38     overcast clouds
# 6        60           0        2.30           clear sky
# 7        95         100        3.18     overcast clouds
# 8        71          40       14.97    scattered clouds
# 9        91         100        8.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
